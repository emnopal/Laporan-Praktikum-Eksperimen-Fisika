# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('Sr-90.csv')
df.head(5)
# Out:
#    n    1/s  R_A1 N_A1 H_A1
# 0  1  1.003    60   40    2
# 1  2  2.027    73   42    3
# 2  3  3.046    63   43    2
# 3  4  4.063    69   45    3
# 4  5  5.085    58   46    1

# %%
#sorting
df.sort_values(["R_A1"], axis=0, ascending=True, inplace=True)
df
# Out:
#        n      1/s  R_A1 N_A1 H_A1
# 42    43   43.949    40  NAN  NAN
# 50    51   52.113    40  NAN  NAN
# 208  209  213.679    42  NAN  NAN
# 99   100  102.208    42  NAN  NAN
# 295  296  302.616    42  NAN  NAN
# ..   ...      ...   ...  ...  ...
# 482  483  493.779    81  NAN  NAN
# 164  165  168.701    81  NAN  NAN
# 371  372  380.238    82  NAN  NAN
# 203  204  208.476    83  NAN  NAN
# 160  161  164.619    83  NAN  NAN
#
# [500 rows x 5 columns]

# %%
#histogram
df['R_A1'].plot.hist(title='Grafik Histogram Distribusi Poisson Sr-90',bins=42, grid=True)

#histogram frequency
df.R_A1.value_counts()
# Out:
# 59    32
# 63    31
# 66    25
# 55    25
# 57    25
# 64    25
# 61    23
# 58    22
# 65    21
# 62    21
# 70    17
# 67    17
# 60    16
# 69    16
# 68    16
# 54    16
# 56    16
# 71    13
# 72    12
# 49    11
# 53     9
# 50     8
# 51     8
# 77     8
# 76     8
# 79     7
# 52     7
# 74     7
# 75     6
# 47     5
# 73     5
# 42     3
# 45     3
# 81     3
# 43     2
# 83     2
# 48     2
# 78     2
# 40     2
# 46     1
# 82     1
# 80     1
# Name: R_A1, dtype: int64
