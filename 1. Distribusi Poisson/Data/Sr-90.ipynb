# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('Sr-90.csv')
df.head(5)
# Out:
#    n    1/s  R_A1 N_A1 H_A1
# 0  1  1.003    60   40    2
# 1  2  2.027    73   42    3
# 2  3  3.046    63   43    2
# 3  4  4.063    69   45    3
# 4  5  5.085    58   46    1

# %%
#sorting
df.sort_values(["R_A1"], axis=0, ascending=True, inplace=True)
df
# Out:
#        n      1/s  R_A1 N_A1 H_A1
# 42    43   43.949    40  NAN  NAN
# 50    51   52.113    40  NAN  NAN
# 208  209  213.679    42  NAN  NAN
# 99   100  102.208    42  NAN  NAN
# 295  296  302.616    42  NAN  NAN
# ..   ...      ...   ...  ...  ...
# 482  483  493.779    81  NAN  NAN
# 164  165  168.701    81  NAN  NAN
# 371  372  380.238    82  NAN  NAN
# 203  204  208.476    83  NAN  NAN
# 160  161  164.619    83  NAN  NAN
#
# [500 rows x 5 columns]

# %%
#histogram
df['R_A1'].plot.hist(title='Grafik Histogram Distribusi Poisson Sr-90',bins=43, grid=True)
plt.xlabel("n",fontsize=12)
plt.ylabel("Wn",fontsize=12)
plt.savefig('Sr-90.png',dpi = 300)

# %%
#histogram frequency
frequency = df['R_A1'].value_counts().sort_index()
print(frequency)
frequency.to_csv('Sr-90-Histogram.csv',index=True, index_label=True)
# Out:
# 40     2
# 42     3
# 43     2
# 45     3
# 46     1
# 47     5
# 48     2
# 49    11
# 50     8
# 51     8
# 52     7
# 53     9
# 54    16
# 55    25
# 56    16
# 57    25
# 58    22
# 59    32
# 60    16
# 61    23
# 62    21
# 63    31
# 64    25
# 65    21
# 66    25
# 67    17
# 68    16
# 69    16
# 70    17
# 71    13
# 72    12
# 73     5
# 74     7
# 75     6
# 76     8
# 77     8
# 78     2
# 79     7
# 80     1
# 81     3
# 82     1
# 83     2
# Name: R_A1, dtype: int64
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   after removing the cwd from sys.path.
